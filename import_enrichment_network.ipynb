# %%
import pandas as pd
import py4cytoscape as p4c
import glob

# %%
p4c.cytoscape_ping()
p4c.cytoscape_version_info()
# Out:
# You are connected to Cytoscape!
# {'apiVersion': 'v1',
#  'cytoscapeVersion': '3.8.2',
#  'automationAPIVersion': '1.2.0',
#  'py4cytoscapeVersion': '0.0.9'}

# %%
def loadEnrichmentNetworks(ts, cond, ni):
    for t in ts:
        print("Working with tissue: " + t)
        print("Reading interactions\n")
        interactions = pd.read_csv("../regulaciontrans-data-server/" + t 
                                   +"/network_aracne/enrichments/go-" + cond + "-comm-interactions-" + ni + ".tsv",
                                   sep = "\t") 
        print("Reading vertices\n")
        vertices = pd.read_csv("../regulaciontrans-data-server/" + t 
                                   +"/network_aracne/enrichments/go-" + cond + "-comm-vertices-" + ni + ".tsv",
                                   sep = "\t") 
        print("Loading network\n")
        net = p4c.networks.create_network_from_data_frames(nodes = vertices,  edges = interactions, 
                                             node_id_list  = "id", 
                                             source_id_list = "id", 
                                             target_id_list = "comm_tissue",
                                            # interaction_type_list = "interaction_type",
                                            collection =  t + "_" + cond,  title = t + "_" + cond)

# %%
tissues = ["bladder", "brain", "breast", "colorectal", "esophagus",
            "kidney", "liver", "lung", "ovary", "pancreas", "prostate",
            "testis", "thyroid","skin", "uterus"]

# %%
loadEnrichmentNetworks(tissues, "cancer", "100000")
# Out:
# Working with tissue: bladder
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: brain
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: breast
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: colorectal
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: esophagus
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: kidney
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: liver
# Reading interactions
#
# Reading vertices
#
# ...

# %%
loadEnrichmentNetworks(tissues, "normal", "100000")
# Out:
# Working with tissue: bladder
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: brain
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: breast
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: colorectal
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: esophagus
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: kidney
# Reading interactions
#
# Reading vertices
#
# Loading network
#
# Applying default style...
# Applying preferred layout
# Working with tissue: liver
# Reading interactions
#
# Reading vertices
#
# ...
